# %%
import os
os.chdir("..")

from wumpusWorld.agent.NaiveAgent import *
from wumpusWorld.environment.Environment import *
from wumpusWorld.environment.Percept import *
from wumpusWorld.environment.Agent import *
from wumpusWorld.environment.Action import *

# %% [markdown]
# Simulation #1

# %%
i=1

initialEnv = Environment.create()
agent = NaiveAgent.create()
percept = Percept.create(initialEnv.isStench(Coords(0,0)), 
                         initialEnv.isBreeze(Coords(0,0)), 
                         initialEnv.isGlitter(Coords(0,0)))
print("-----INITIAL STATE-----")

while not initialEnv.terminated:
    initialEnv.visualize(agent)
    percept.show()
    agent.show()
    print("\n -----STEP " + str(i) + "-----")
    action = NaiveAgent.nextAction()
    percept, agent = initialEnv.applyAction(percept, action, agent)
    i+=1
percept.show()
agent.show()
# Out:
# -----INITIAL STATE-----
#    W|    |  G | P  |
#     |    | P  |    |
#     |    | P  | P  |
# A   | P  |    | P  |
#
# stench: False, breeze: True, glitter: False, bump: False, scream: False, isTerminated: False, reward: 0
# arrow: True, gold: False, alive: True, orientation: East
#
#  -----STEP 1-----
# Forward
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: True, reward: -1001
# arrow: True, gold: False, alive: False, orientation: East

# %% [markdown]
# Simulation #2

# %%
i=1

initialEnv = Environment.create()
agent = NaiveAgent.create()
percept = Percept.create(initialEnv.isStench(Coords(0,0)), 
                         initialEnv.isBreeze(Coords(0,0)), 
                         initialEnv.isGlitter(Coords(0,0)))
print("-----INITIAL STATE-----")

while not initialEnv.terminated:
    initialEnv.visualize(agent)
    percept.show()
    agent.show()
    print("\n -----STEP " + str(i) + "-----")
    action = NaiveAgent.nextAction()
    percept, agent = initialEnv.applyAction(percept, action, agent)
    i+=1
percept.show()
agent.show()
# Out:
# -----INITIAL STATE-----
#     | P  |   W|    |
#     |    |    |    |
#     | P  |    |    |
# A   |    |    | PG |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: 0
# arrow: True, gold: False, alive: True, orientation: East
#
#  -----STEP 1-----
# Forward
#     | P  |   W|    |
#     |    |    |    |
#     | P  |    |    |
#     |A   |    | PG |
#
# stench: False, breeze: True, glitter: False, bump: False, scream: False, isTerminated: False, reward: -1
# arrow: True, gold: False, alive: True, orientation: East
#
#  -----STEP 2-----
# Shoot
#     | P  |   W|    |
#     |    |    |    |
#     | P  |    |    |
#     |A   |    | PG |
#
# stench: False, breeze: True, glitter: False, bump: False, scream: False, isTerminated: False, reward: -12
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 3-----
# TurnRight
#     | P  |   W|    |
#     |    |    |    |
#     | P  |    |    |
#     |A   |    | PG |
#
# stench: False, breeze: True, glitter: False, bump: False, scream: False, isTerminated: False, reward: -13
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 4-----
# TurnLeft
#     | P  |   W|    |
#     |    |    |    |
#     | P  |    |    |
#     |A   |    | PG |
#
# stench: False, breeze: True, glitter: False, bump: False, scream: False, isTerminated: False, reward: -14
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 5-----
# Forward
#     | P  |   W|    |
#     |    |    |    |
#     | P  |    |    |
#     |    |A   | PG |
#
# stench: False, breeze: True, glitter: False, bump: False, scream: False, isTerminated: False, reward: -15
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 6-----
# Grab
#     | P  |   W|    |
#     |    |    |    |
#     | P  |    |    |
#     |    |A   | PG |
#
# stench: False, breeze: True, glitter: False, bump: False, scream: False, isTerminated: False, reward: -16
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 7-----
# Grab
#     | P  |   W|    |
#     |    |    |    |
#     | P  |    |    |
#     |    |A   | PG |
#
# stench: False, breeze: True, glitter: False, bump: False, scream: False, isTerminated: False, reward: -17
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 8-----
# Forward
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: True, reward: -1018
# arrow: False, gold: False, alive: False, orientation: East

# %% [markdown]
# Simulation #3

# %%
i=1

initialEnv = Environment.create()
agent = NaiveAgent.create()
percept = Percept.create(initialEnv.isStench(Coords(0,0)), 
                         initialEnv.isBreeze(Coords(0,0)), 
                         initialEnv.isGlitter(Coords(0,0)))
print("-----INITIAL STATE-----")

while not initialEnv.terminated:
    initialEnv.visualize(agent)
    percept.show()
    agent.show()
    print("\n -----STEP " + str(i) + "-----")
    action = NaiveAgent.nextAction()
    percept, agent = initialEnv.applyAction(percept, action, agent)
    i+=1
percept.show()
agent.show()
# Out:
# -----INITIAL STATE-----
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
# A   |    |    |   W|
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: 0
# arrow: True, gold: False, alive: True, orientation: East
#
#  -----STEP 1-----
# Forward
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |A   |    |   W|
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -1
# arrow: True, gold: False, alive: True, orientation: East
#
#  -----STEP 2-----
# Grab
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |A   |    |   W|
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -2
# arrow: True, gold: False, alive: True, orientation: East
#
#  -----STEP 3-----
# TurnRight
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |A   |    |   W|
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -3
# arrow: True, gold: False, alive: True, orientation: South
#
#  -----STEP 4-----
# TurnLeft
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |A   |    |   W|
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -4
# arrow: True, gold: False, alive: True, orientation: East
#
#  -----STEP 5-----
# TurnRight
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |A   |    |   W|
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -5
# arrow: True, gold: False, alive: True, orientation: South
#
#  -----STEP 6-----
# Shoot
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |A   |    |   W|
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -16
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 7-----
# TurnLeft
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |A   |    |   W|
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -17
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 8-----
# Forward
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -18
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 9-----
# TurnRight
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -19
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 10-----
# Forward
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: True, scream: False, isTerminated: False, reward: -20
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 11-----
# Grab
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -21
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 12-----
# Climb
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -22
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 13-----
# TurnLeft
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -23
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 14-----
# Grab
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -24
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 15-----
# TurnLeft
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -25
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 16-----
# Shoot
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -26
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 17-----
# TurnRight
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -27
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 18-----
# TurnLeft
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -28
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 19-----
# Shoot
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -29
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 20-----
# TurnLeft
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -30
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 21-----
# TurnRight
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -31
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 22-----
# Shoot
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -32
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 23-----
# TurnLeft
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -33
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 24-----
# Grab
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -34
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 25-----
# TurnLeft
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -35
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 26-----
# TurnLeft
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -36
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 27-----
# Shoot
#  P  |  G |    |    |
#     | P  |    |    |
#     |    |    |    |
#     |    |A   |   W|
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -37
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 28-----
# Forward
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: True, reward: -1038
# arrow: False, gold: False, alive: False, orientation: East

# %% [markdown]
# Simulation #4

# %%
i=1

initialEnv = Environment.create(pitProb = 0,
               allowClimbWithoutGold = False,)
agent = NaiveAgent.create()
percept = Percept.create(initialEnv.isStench(Coords(0,0)), 
                         initialEnv.isBreeze(Coords(0,0)), 
                         initialEnv.isGlitter(Coords(0,0)))
print("-----INITIAL STATE-----")

while not initialEnv.terminated:
    initialEnv.visualize(agent)
    percept.show()
    agent.show()
    print("\n -----STEP " + str(i) + "-----")
    action = NaiveAgent.nextAction()
    percept, agent = initialEnv.applyAction(percept, action, agent)
    i+=1
percept.show()
agent.show()
# Out:
# -----INITIAL STATE-----
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: 0
# arrow: True, gold: False, alive: True, orientation: East
#
#  -----STEP 1-----
# Grab
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -1
# arrow: True, gold: False, alive: True, orientation: East
#
#  -----STEP 2-----
# TurnRight
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -2
# arrow: True, gold: False, alive: True, orientation: South
#
#  -----STEP 3-----
# TurnRight
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -3
# arrow: True, gold: False, alive: True, orientation: West
#
#  -----STEP 4-----
# TurnRight
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -4
# arrow: True, gold: False, alive: True, orientation: North
#
#  -----STEP 5-----
# TurnRight
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -5
# arrow: True, gold: False, alive: True, orientation: East
#
#  -----STEP 6-----
# Shoot
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -16
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 7-----
# TurnRight
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -17
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 8-----
# Shoot
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -18
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 9-----
# Grab
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -19
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 10-----
# Forward
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: True, scream: False, isTerminated: False, reward: -20
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 11-----
# TurnLeft
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -21
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 12-----
# Shoot
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -22
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 13-----
# Forward
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |A   |    |    |
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -23
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 14-----
# TurnRight
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |A   |    |    |
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -24
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 15-----
# Forward
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |A   |    |    |
#
# stench: True, breeze: False, glitter: False, bump: True, scream: False, isTerminated: False, reward: -25
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 16-----
# Forward
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |A   |    |    |
#
# stench: True, breeze: False, glitter: False, bump: True, scream: False, isTerminated: False, reward: -26
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 17-----
# Climb
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |A   |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -27
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 18-----
# TurnRight
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |A   |    |    |
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -28
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 19-----
# Forward
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -29
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 20-----
# TurnRight
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -30
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 21-----
# TurnRight
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -31
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 22-----
# TurnLeft
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -32
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 23-----
# Shoot
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -33
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 24-----
# Shoot
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -34
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 25-----
# TurnLeft
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -35
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 26-----
# Grab
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -36
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 27-----
# Forward
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: True, scream: False, isTerminated: False, reward: -37
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 28-----
# Shoot
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -38
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 29-----
# Forward
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: True, scream: False, isTerminated: False, reward: -39
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 30-----
# TurnLeft
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -40
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 31-----
# TurnRight
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -41
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 32-----
# Shoot
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -42
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 33-----
# Forward
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: True, scream: False, isTerminated: False, reward: -43
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 34-----
# TurnRight
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -44
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 35-----
# Grab
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -45
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 36-----
# Climb
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -46
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 37-----
# Grab
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -47
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 38-----
# Climb
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -48
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 39-----
# TurnLeft
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -49
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 40-----
# Shoot
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -50
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 41-----
# Grab
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -51
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 42-----
# TurnLeft
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -52
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 43-----
# Climb
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -53
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 44-----
# Shoot
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -54
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 45-----
# Climb
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -55
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 46-----
# TurnRight
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -56
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 47-----
# TurnRight
#   G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A   |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -57
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 48-----
# Forward
#   G |    |    |    |
#     |    |    |    |
# A   |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -58
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 49-----
# Grab
#   G |    |    |    |
#     |    |    |    |
# A   |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -59
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 50-----
# Climb
#   G |    |    |    |
#     |    |    |    |
# A   |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -60
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 51-----
# Climb
#   G |    |    |    |
#     |    |    |    |
# A   |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -61
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 52-----
# Forward
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -62
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 53-----
# TurnLeft
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -63
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 54-----
# Forward
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: True, scream: False, isTerminated: False, reward: -64
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 55-----
# TurnRight
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -65
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 56-----
# Climb
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -66
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 57-----
# TurnLeft
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -67
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 58-----
# Climb
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -68
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 59-----
# Grab
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -69
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 60-----
# Forward
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: True, scream: False, isTerminated: False, reward: -70
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 61-----
# Shoot
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -71
# arrow: False, gold: False, alive: True, orientation: West
#
#  -----STEP 62-----
# TurnLeft
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -72
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 63-----
# TurnLeft
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -73
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 64-----
# Shoot
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -74
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 65-----
# Shoot
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -75
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 66-----
# TurnRight
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -76
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 67-----
# TurnLeft
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -77
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 68-----
# Climb
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -78
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 69-----
# TurnLeft
#   G |    |    |    |
# A   |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: False, bump: False, scream: False, isTerminated: False, reward: -79
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 70-----
# Forward
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -80
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 71-----
# TurnRight
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -81
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 72-----
# TurnRight
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -82
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 73-----
# Shoot
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -83
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 74-----
# Shoot
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -84
# arrow: False, gold: False, alive: True, orientation: South
#
#  -----STEP 75-----
# TurnLeft
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -85
# arrow: False, gold: False, alive: True, orientation: East
#
#  -----STEP 76-----
# TurnLeft
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -86
# arrow: False, gold: False, alive: True, orientation: North
#
#  -----STEP 77-----
# Grab
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -87
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 78-----
# Shoot
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -88
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 79-----
# Forward
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: True, scream: False, isTerminated: False, reward: -89
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 80-----
# TurnLeft
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -90
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 81-----
# TurnLeft
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -91
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 82-----
# Grab
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -92
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 83-----
# Forward
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -93
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 84-----
# Forward
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -94
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 85-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -95
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 86-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -96
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 87-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -97
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 88-----
# Climb
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -98
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 89-----
# TurnRight
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -99
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 90-----
# TurnLeft
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -100
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 91-----
# Climb
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -101
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 92-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -102
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 93-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -103
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 94-----
# Climb
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -104
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 95-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -105
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 96-----
# TurnRight
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -106
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 97-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -107
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 98-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -108
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 99-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -109
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 100-----
# TurnLeft
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -110
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 101-----
# TurnRight
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -111
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 102-----
# TurnLeft
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -112
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 103-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -113
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 104-----
# Climb
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -114
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 105-----
# TurnRight
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -115
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 106-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -116
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 107-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -117
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 108-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -118
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 109-----
# Climb
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -119
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 110-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -120
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 111-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -121
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 112-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -122
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 113-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -123
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 114-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -124
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 115-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -125
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 116-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -126
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 117-----
# Forward
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: True, scream: False, isTerminated: False, reward: -127
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 118-----
# TurnLeft
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -128
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 119-----
# TurnRight
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -129
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 120-----
# Forward
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: True, scream: False, isTerminated: False, reward: -130
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 121-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -131
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 122-----
# TurnLeft
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -132
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 123-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -133
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 124-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -134
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 125-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -135
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 126-----
# TurnLeft
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -136
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 127-----
# TurnLeft
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -137
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 128-----
# TurnLeft
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -138
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 129-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -139
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 130-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -140
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 131-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -141
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 132-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -142
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 133-----
# TurnRight
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -143
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 134-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -144
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 135-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -145
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 136-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -146
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 137-----
# Climb
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -147
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 138-----
# TurnLeft
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -148
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 139-----
# Climb
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -149
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 140-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -150
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 141-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -151
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 142-----
# Climb
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -152
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 143-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -153
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 144-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -154
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 145-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -155
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 146-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -156
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 147-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -157
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 148-----
# TurnLeft
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -158
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 149-----
# Shoot
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -159
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 150-----
# TurnLeft
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -160
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 151-----
# TurnLeft
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -161
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 152-----
# Climb
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -162
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 153-----
# Grab
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -163
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 154-----
# TurnLeft
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -164
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 155-----
# Forward
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: True, scream: False, isTerminated: False, reward: -165
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 156-----
# TurnRight
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -166
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 157-----
# Forward
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -167
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 158-----
# Grab
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -168
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 159-----
# Shoot
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -169
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 160-----
# TurnRight
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -170
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 161-----
# Climb
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -171
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 162-----
# TurnRight
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -172
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 163-----
# Shoot
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -173
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 164-----
# TurnLeft
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -174
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 165-----
# Climb
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -175
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 166-----
# TurnRight
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -176
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 167-----
# Climb
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -177
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 168-----
# Climb
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -178
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 169-----
# TurnLeft
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -179
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 170-----
# Shoot
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -180
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 171-----
# Shoot
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -181
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 172-----
# Grab
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -182
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 173-----
# TurnLeft
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
# ...
# TurnRight
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -203
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 194-----
# Climb
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -204
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 195-----
# Forward
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -205
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 196-----
# Shoot
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -206
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 197-----
# TurnRight
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -207
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 198-----
# TurnLeft
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -208
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 199-----
# Climb
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -209
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 200-----
# TurnLeft
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -210
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 201-----
# TurnLeft
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -211
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 202-----
# Forward
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -212
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 203-----
# Climb
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -213
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 204-----
# Grab
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -214
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 205-----
# Shoot
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -215
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 206-----
# Climb
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -216
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 207-----
# Grab
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -217
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 208-----
# TurnLeft
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -218
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 209-----
# TurnLeft
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -219
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 210-----
# Forward
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -220
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 211-----
# Climb
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -221
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 212-----
# Shoot
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -222
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 213-----
# Forward
#     |    |A G |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -223
# arrow: False, gold: True, alive: True, orientation: East
#
#  -----STEP 214-----
# TurnRight
#     |    |A G |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -224
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 215-----
# TurnRight
#     |    |A G |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -225
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 216-----
# Forward
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -226
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 217-----
# TurnRight
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -227
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 218-----
# Shoot
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -228
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 219-----
# Grab
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -229
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 220-----
# Shoot
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -230
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 221-----
# Forward
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: True, scream: False, isTerminated: False, reward: -231
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 222-----
# Climb
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -232
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 223-----
# Shoot
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -233
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 224-----
# Forward
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: True, scream: False, isTerminated: False, reward: -234
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 225-----
# Shoot
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -235
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 226-----
# Forward
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: True, scream: False, isTerminated: False, reward: -236
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 227-----
# TurnLeft
#     |A G |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -237
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 228-----
# Forward
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -238
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 229-----
# Shoot
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -239
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 230-----
# Shoot
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -240
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 231-----
# Climb
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -241
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 232-----
# Grab
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -242
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 233-----
# TurnRight
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -243
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 234-----
# Climb
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -244
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 235-----
# Grab
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -245
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 236-----
# Grab
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -246
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 237-----
# Grab
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -247
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 238-----
# Shoot
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -248
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 239-----
# Grab
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -249
# arrow: False, gold: True, alive: True, orientation: North
#
#  -----STEP 240-----
# TurnLeft
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -250
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 241-----
# TurnLeft
# A G |    |    |    |
#     |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -251
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 242-----
# Forward
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -252
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 243-----
# Climb
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -253
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 244-----
# TurnRight
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -254
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 245-----
# Forward
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: True, scream: False, isTerminated: False, reward: -255
# arrow: False, gold: True, alive: True, orientation: West
#
#  -----STEP 246-----
# TurnLeft
#     |    |    |    |
# A G |    |    |    |
#     |   W|    |    |
#     |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -256
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 247-----
# Forward
#     |    |    |    |
#     |    |    |    |
# A G |   W|    |    |
#     |    |    |    |
#
# stench: True, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -257
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 248-----
# Forward
#     |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A G |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -258
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 249-----
# Shoot
#     |    |    |    |
#     |    |    |    |
#     |   W|    |    |
# A G |    |    |    |
#
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: False, reward: -259
# arrow: False, gold: True, alive: True, orientation: South
#
#  -----STEP 250-----
# Climb
# stench: False, breeze: False, glitter: True, bump: False, scream: False, isTerminated: True, reward: 740
# arrow: False, gold: True, alive: True, orientation: South
